# %% [markdown]
# This is a notebook for testing the helpers.py file for the API. Specifically, the pdf to csv functionality

# %%
# Fix pathing
import sys
sys.path.append("..")

# %%
from API.helpers import *
from pdf_parser.pdf_parsing import *
import os

# %%
filename = "Oxy.pdf"
file = os.path.join(os.path.abspath('..'), f'heat_sheets/{filename}')
meet_info_from_pdf = extract_dict_from_heat_sheet(file)

# %%
print(meet_info_from_pdf)
# Out:
# [{'event_number': '11', 'gender': 'Women', 'distance': '800', 'type': 'Run', 'athletes_list': [{'name': 'Wurzbach, Hailey', 'year': 'FR', 'school': 'Biola', 'time': '2:15.00', 'seed': '3'}, {'name': 'Stewart, Harper', 'year': None, 'school': 'Sprint Academy', 'time': '2:19.17', 'seed': '7'}, {'name': 'Degollado, Fernanda', 'year': 'FR', 'school': 'Mt', 'time': '2:22.56', 'seed': '11'}, {'name': 'Williams, Maggie', 'year': 'FR', 'school': 'Biola', 'time': '2:10.00', 'seed': '1'}, {'name': 'Bullock, Chloe', 'year': 'SO', 'school': 'Redlands', 'time': '2:18.66', 'seed': '5'}, {'name': 'Hawley, Elizabeth', 'year': 'FR', 'school': 'Occidental', 'time': '2:20.00', 'seed': '9'}, {'name': 'Champness, Hannah', 'year': 'JR', 'school': 'Biola', 'time': '2:14.00', 'seed': '2'}, {'name': 'Garcia, Sidney', 'year': 'FR', 'school': 'San Diego Mesa College', 'time': '2:19.07', 'seed': '6'}, {'name': 'Chavez, Ariana', 'year': 'SO', 'school': 'Chabot', 'time': '2:20.56', 'seed': '10'}, {'name': 'Lopez,
# ...

# %%
csv_file = create_csv(filename,meet_info_from_pdf)
# Out:
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# Invalid distance
# ...
